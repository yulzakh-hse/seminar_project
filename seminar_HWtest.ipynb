# %%
print ('Hello world')
# Out:
# Hello world

# %%
import numpy as np

# %%
x = [1, 2, 3]
y = [8, 9, 10]

# %%
x + y  # List concatenation
# Out:
# [1, 2, 3, 8, 9, 10]

# %%
# Convert to numpy arrays
a = np.array(x)
b = np.array(y)

a + b
# Out:
# array([ 9, 11, 13])
